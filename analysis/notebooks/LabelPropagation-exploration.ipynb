# %% [markdown]
# # Exploring ways to propagate labels from anchor actions to all activities
# ## Results -- strategy for label propagation:
# * Consecutive events sharing the same tab-url are assumed to belong to the same task.
# * Exception: Multiple anchor events with different labels may be included in the same segment.
#
# ## Exception handling:
# * Loglikelihood testing for consecutive events: p(i, j)/p(i)p(j) ~ Chi square p-value < 0.5
# * non-exchangable: p(i|j) > p(j|i)

# %%
# %matplotlib inline
from pymongo import MongoClient
import pymongo
import numpy as np
import itertools
import matplotlib.pylab as pylab

# DB connections
client = MongoClient()
db = client.db_tasklog_clean
# Collections
User = db.user
Log = db.log_chrome

# users
allUsers = list(User.find({}))

# %% [markdown]
# ## Log segmentation and annotation

# %% [markdown]
# ### Setup

# %%
userLogs = {}
for u in allUsers:
    user_log = Log.aggregate([
        {'$match': {'userid': u['userid'], 'removed': False}},
        {'$project': {'affected_tab_id': 1, 
                     'event': 1, 
                     'url': 1,
                     'timestamp_bson': 1, 
                     'taskname': {'$ifNull': ['$annotation.task.name', 'NA']},
                     'taskid': {'$ifNull': ['$annotation.task.taskid', 'NA']},
                     'title': {'$ifNull': ['$details.current_tab.title', 'NA']},
                     }}, 
        {'$sort':{'timestamp_bson': pymongo.ASCENDING}},
        ])
    userLogs[u['userid']] = list(user_log)

# %% [markdown]
# ### Group log by tab and urls:
#
# * Assumption: consecutive same (tab, url) belong to the same task
#
# #### Check:
# * Time distribution within a tab-url segment, see if there are exceptionally long pauses
#
# #### Check result:
# * < 3% consecutive tabs with same URLs have a time gap > 1 min
# * < 1% consecutive tabs with same URLs have a time gap > 5 mins
# * Most of the consecutive tab with same URLs are due to the chrome event fire mechanism, e.g., click a link -> navigation_link -> tab_loaded.
# * We can assume that if the gap is less than 5 min, then they belong to the same task. It is not superising that a user spend 5 mins on the same page not doing anything.

# %%
# Group by tab
tabs = []
for u in userLogs:
    group = []
    current_tab = 0
    current_url = '$'
    for l in userLogs[u]:
        # If there is different tab_id or url
        if not (current_tab == l['affected_tab_id'] or current_url == l['url']):
            if not current_tab == 0:
                tabs.append(group)
                group = []
        current_tab = l['affected_tab_id']
        current_url = l['url']
        l['userid'] = u
        group.append(l)
    tabs.append(group)

# Check time gap distribution
t_gap = []
len_groups = []
for tab in tabs:
    if len(tab) > 1:
        len_groups.append(len(tab))
        for i in range(len(tab)-1):
            j = i + 1
            gap_min = (tab[j]['timestamp_bson'] - tab[i]['timestamp_bson']).total_seconds()/60
            t_gap.append(gap_min)
#    if len(tab)> 100:
#        for t in tab:
#            print t['userid'], t['event'], t['affected_tab_id'], len(tab)
            
x_1 = list(itertools.ifilter(lambda x: x>1, t_gap))
x_5 = list(itertools.ifilter(lambda x: x>5, t_gap))
x_10 = list(itertools.ifilter(lambda x: x>10, t_gap))
x_30 = list(itertools.ifilter(lambda x: x>30, t_gap))
tot = float(len(t_gap))

print 'Distribution of time gap'
print len(x_1)/tot, len(x_5)/tot, len(x_10)/tot, len(x_30)/tot
mean = np.mean(t_gap)
std = np.std(t_gap)
print 'Mean:', mean, 'Std:', std

print

#pylab.hist(x_1, 100)
print 'Group length > 1:', len(len_groups)/float(len(tabs))
x_20 = list(itertools.ifilter(lambda x: x>20, len_groups))
print 'Group length > 20:', len(x_20)/float(len(tabs))
x_50 = list(itertools.ifilter(lambda x: x>50, len_groups))
print 'Group length > 50:', len(x_50)/float(len(tabs))
mean = np.mean([len(t) for t in tabs])
std = np.std([len(t) for t in tabs])
print 'group length: ', 'Mean:', mean, 'Std:', std
#pylab.hist(len_groups, 20)
# Out:
# Distribution of time gap
# 0.0248382693335 0.00520802421509 0.00289334678616 0.0012908777969
# Mean: 0.440881743476 Std: 14.4789145226
#
# Group length > 1: 0.465919160248
# Group length > 20: 0.0187103810238
# Group length > 50: 0.00374889237271
# group length:  Mean: 3.29691227592 Std: 7.12319726981

# %% [markdown]
# ### Problem of tab-url groups:
# It is possible that consecutive events within a tab-url group are assigned to different task labels by users.
# It is hard to know where the boundary is. Most likely a group of events as the result of chrome event firing
# sequence should be grouped together.
#
# What we need is to check what are the common combination of events with tab-loaded and tab-search
# The reason there are two different tasks is because there are two tab-loaded/tab-search events within the same group.

# %%
# Bigrams of tab-search/tab-loaded
keys = ['tab-loaded', 'tab-search']
pairs = []
singles = []
for group in tabs:
    prev = group[0]
    singles.append(prev['event'])
    for l in group[1:]:
        if (prev['event'] in keys) or (l['event'] in keys):
            time_gap = (l['timestamp_bson'] - prev['timestamp_bson']).total_seconds()
            pairs.append((prev['event'], l['event'], time_gap))
        singles.append(l['event'])
        prev = l

# Indications of non-random combination:
# - p(a_i, a_j) > p(a_i)p(a_j)
# - p(a_i|a_j) > p(a_j|a_i): not switchable due to chrome event firing sequence
            
# count the singles
singles.sort()
single_count = []
for k, g in itertools.groupby(singles):
    single_count.append((k, len(list(g))))
single_count = dict(single_count)

# compare to joint probability and switched conditional probability
pairs.sort(key=lambda x: (x[0], x[1]))
tot_single = float(len(singles))
stats = []
for k, g in itertools.groupby(pairs, lambda x: (x[0], x[1])):
    # Likelihood ratio
    g = list(g)
    p_pair = len(g)/float(len(pairs))
    p_single = single_count.get(k[0])/tot_single * single_count.get(k[1])/tot_single
    lr_joint = p_pair/p_single
#    time_gap = [x[2] for x in g]
    p_ij = len(g)/float(single_count[k[0]])
    p_ji = 0
    if k[0] in single_count:
        p_ji = len(g)/float(single_count[k[1]])
    if lr_joint > 1 and (p_ij > p_ji):
        stats.append((k, lr_joint, p_ij, p_ji))
        
stats.sort(key=lambda x: x[1], reverse=True)
for s in stats:
    print s
# Out:
# ((u'tab-replace-switch', u'tab-search'), 53.901885248053304, 0.7805953693495039, 0.233201581027668)
# ((u'tab-open-in-new', u'tab-search'), 9.121481170165625, 0.13209530483531884, 0.12417654808959157)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 6.940292510127106, 0.9942857142857143, 0.005793434108010921)
# ((u'navigation-form_submit', u'tab-loaded'), 6.618495912952857, 0.9481842338352524, 0.07128587600719184)
# ((u'navigation-link-forward_back', u'tab-loaded'), 6.5138310661276435, 0.9331896551724138, 0.028833988146766996)
# ((u'navigation-keyword', u'tab-loaded'), 6.204603776614272, 0.8888888888888888, 0.00026636478657521474)
# ((u'navigation-manual_subframe', u'tab-loaded'), 5.505590542649707, 0.788746298124383, 0.026603183059199575)
# ((u'navigation-link', u'tab-loaded'), 5.437433555959008, 0.7789819376026272, 0.23693147765865352)
# ((u'tab-search', u'navigation-link'), 4.958762088371499, 0.2160737812911726, 0.07181171319102353)
# ((u'navigation-reload', u'tab-loaded'), 4.930337741877752, 0.7063339731285988, 0.012252780182459878)
# ((u'navigation-omni_url-forward_back', u'tab-search'), 4.528017960543147, 0.06557377049180328, 0.0013175230566534915)
# ((u'navigation-omni_url-forward_back', u'tab-loaded'), 4.348308384430494, 0.6229508196721312, 0.00126523273623227)
# ((u'navigation-start_page', u'tab-loaded'), 3.751846346171443, 0.5375, 0.0014317107278417794)
# ((u'tab-search', u'tab-loaded'), 3.4027224268981433, 0.4874835309617918, 0.04927748551641473)
# ((u'navigation-omni_query', u'tab-loaded'), 2.0653306333488235, 0.2958850424559112, 0.015082906039821535)
# ((u'navigation-omni_url', u'tab-loaded'), 2.0167944437305656, 0.28893161219445207, 0.03502696943464074)
# ((u'form_submit', u'tab-search'), 1.4616124056941677, 0.021166752710376872, 0.013504611330698288)
# ((u'link_click', u'tab-loaded'), 1.363599481475501, 0.19535307517084283, 0.07138576280215755)

# %% [markdown]
# ### 2. Check transition patterns between events
#
# #### Level-0: Pattern forms because of the way chrome API sending events

# %%
# Find sequences of events commonly appear in one tab-url group
pairs = []
singles = []
for group in tabs:
    prev = group[0]
    singles.append(prev['event'])
    for l in group[1:]:
        time_gap = (l['timestamp_bson'] - prev['timestamp_bson']).total_seconds()
        pairs.append((prev['event'], l['event'], time_gap))
        prev = l
        singles.append(l['event'])
      
# count the singles
singles.sort()
single_count = []
for k, g in itertools.groupby(singles):
    single_count.append((k, len(list(g))))
single_count = dict(single_count)

pairs.sort(key=lambda x: (x[0], x[1]))
tot_single = float(len(singles))
stats = []
for k, g in itertools.groupby(pairs, lambda x: (x[0], x[1])):
    # Likelihood ratio
    g = list(g)
    p_pair = len(g)/float(len(pairs))
    p_single = single_count.get(k[0])/tot_single * single_count.get(k[1])/tot_single
    lr = p_pair/p_single
    time_gap = [x[2] for x in g]
    stats.append((k, len(g), lr, np.mean(time_gap), np.std(time_gap)))
        
stats.sort(key=lambda x: x[2], reverse=True)
#for s in stats:
#    print s

# %%
# Check if a sequence of event is likely to be together by chance, in all data, not limited to tab-url groups
pairs = []
singles = []
for u in userLogs:
    prev = userLogs[u][0]
    singles.append(prev['event'])
    for l in userLogs[u][1:]:
        #also get time gap
        time_gap = (l['timestamp_bson'] - prev['timestamp_bson']).total_seconds()
        pairs.append((prev['event'], l['event'], time_gap))
        singles.append(l['event'])
        prev = l
        
# count the singles
singles.sort()
single_count = []
for k, g in itertools.groupby(singles):
    single_count.append((k, len(list(g))))
single_count = dict(single_count)

pairs.sort(key=lambda x: (x[0], x[1]))
tot_single = float(len(singles))
stats = []
for k, g in itertools.groupby(pairs, lambda x: (x[0], x[1])):
    # Likelihood ratio
    g = list(g)
    p_pair = len(g)/float(len(pairs))
    p_single = single_count.get(k[0])/tot_single * single_count.get(k[1])/tot_single
    lr = p_pair/p_single
    time_gap = [x[2] for x in g]
    stats.append((k, len(g), lr, np.mean(time_gap), np.std(time_gap)))
        
stats.sort(key=lambda x: x[2], reverse=True)
#for s in stats:
#    print s

# %% [markdown]
# There are two types of events:
# * Active events: triggered by user doing something
# * Passive events: triggered by the active events
#
# Active events:
# * form_submit
# * link_click
# * navigation-link-forward_back: triggered by user clicking forward/backward
# * navigation-omni_query: triggered by user typing in query in omnibox
# * navigation-omni_query-forward_back: triggered by user clicking forward/backward to a SERP
# * navigation-omni_url: triggered by user typing in a url in omnibox
# * navigation-omni_url-forward_back: triggered by user clicking forward/backward
# * tab-close: triggered by user closing a tab
# * tab-new: triggered by user open a new tab
# * tab-open-in-new: triggered by user open a page in new tab
# * tab-switch: triggered by user switching to a differen tab
#
# Passive events:
# * navigation-link: triggered by link_click, or form_submit, or other interactions with links
# * navigation-manual_subframe: not sure how it is triggered
# * navigation-reload: this can be triggered by user or automatic reloading
# * navigation-start_page: not sure how it's triggered
# * tab-close-switch: this is triggered by tab-clost
# * tab-loaded: this can be triggered by any events that loading a page
# * tab-new-switch: triggered by tab-new
# * tab-replace: this is something special with Google pre-loading some SERP
# * tab-replace-switch: this is something special with Google pre-loading some SERP
# * tab-search: triggered by form_submit or omni-query

# %%
# See the time distribution between events to determine:
# - frequent occuring segments of events
# - time gap that are exceptionally long for an indication of split
for u in allUsers:
    user_log = Log.aggregate([{'$match': {'userid': u['userid'], 'removed': False}},
                              {'$project': {'event': 1, 'timestamp_bson': 1}},
                              {'$sort':{'timestamp_bson': pymongo.ASCENDING}},
                             ])
    user_log = list(user_log)
    tuples = []
    # Get the transition types
    for i in range(len(user_log)-1):
        j = i + 1
        # Time gap in terms of milliseconds
        time_gap = (user_log[j]['timestamp_bson'] - user_log[i]['timestamp_bson']).total_seconds()*1000
        tuples.append(((user_log[i]['event'], user_log[j]['event']), time_gap))
        
    # Aggregate the tuples
    tuples.sort(key=lambda x: x[0])
    top_tuples = []
    for k, g in itertools.groupby(tuples, lambda x: x[0]):
        time_gaps = [x[1] for x in list(g)]
        top_tuples.append((k, float(len(time_gaps))/len(tuples)))
        
    top_tuples.sort(key=lambda x: x[1], reverse=True)
    for t in top_tuples:
        print t
# Out:
# ((u'tab-loaded', u'tab-loaded'), 0.24097331240188383)
# ((u'tab-loaded', u'link_click'), 0.14285714285714285)
# ((u'link_click', u'tab-loaded'), 0.09379905808477237)
# ((u'tab-switch', u'tab-switch'), 0.08634222919937205)
# ((u'navigation-link', u'tab-loaded'), 0.06789638932496075)
# ((u'link_click', u'navigation-link'), 0.05729984301412873)
# ((u'link_click', u'link_click'), 0.04277864992150707)
# ((u'tab-loaded', u'tab-switch'), 0.023547880690737835)
# ((u'tab-close', u'tab-close-switch'), 0.02315541601255887)
# ((u'tab-switch', u'link_click'), 0.018838304552590265)
# ((u'tab-new', u'tab-new-switch'), 0.012951334379905808)
# ((u'link_click', u'tab-open-in-new'), 0.01216640502354788)
# ((u'tab-open-in-new', u'navigation-link'), 0.01020408163265306)
# ((u'tab-switch', u'tab-loaded'), 0.00902668759811617)
# ((u'navigation-form_submit', u'tab-loaded'), 0.007849293563579277)
# ((u'navigation-link', u'link_click'), 0.007849293563579277)
# ((u'tab-loaded', u'tab-close'), 0.007849293563579277)
# ((u'tab-close-switch', u'tab-switch'), 0.00706436420722135)
# ((u'tab-switch', u'tab-close'), 0.006279434850863423)
# ((u'tab-loaded', u'tab-new'), 0.005886970172684459)
# ((u'link_click', u'tab-switch'), 0.005494505494505495)
# ((u'tab-close-switch', u'tab-close'), 0.005494505494505495)
# ((u'tab-loaded', u'navigation-link'), 0.00510204081632653)
# ((u'navigation-omni_query', u'tab-loaded'), 0.004709576138147566)
# ((u'tab-open-in-new', u'tab-open-in-new'), 0.004709576138147566)
# ((u'tab-search', u'navigation-omni_query'), 0.004709576138147566)
# ((u'navigation-reload', u'navigation-reload'), 0.0043171114599686025)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.0043171114599686025)
# ((u'tab-close-switch', u'tab-new'), 0.003924646781789639)
# ((u'tab-loaded', u'form_submit'), 0.003532182103610675)
# ((u'tab-new-switch', u'tab-close'), 0.003532182103610675)
# ((u'form_submit', u'navigation-form_submit'), 0.0031397174254317113)
# ((u'navigation-omni_url', u'tab-loaded'), 0.0031397174254317113)
# ((u'tab-close-switch', u'tab-loaded'), 0.0031397174254317113)
# ((u'tab-loaded', u'tab-search'), 0.0031397174254317113)
# ((u'tab-new-switch', u'tab-search'), 0.0031397174254317113)
# ((u'navigation-reload', u'tab-loaded'), 0.0027472527472527475)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.0027472527472527475)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.002354788069073783)
# ((u'tab-loaded', u'navigation-form_submit'), 0.002354788069073783)
# ((u'tab-open-in-new', u'tab-loaded'), 0.002354788069073783)
# ((u'tab-open-in-new', u'tab-switch'), 0.002354788069073783)
# ((u'tab-switch', u'navigation-link'), 0.002354788069073783)
# ((u'tab-close-switch', u'link_click'), 0.0015698587127158557)
# ((u'tab-loaded', u'tab-open-in-new'), 0.0015698587127158557)
# ((u'tab-search', u'navigation-form_submit'), 0.0015698587127158557)
# ((u'tab-switch', u'navigation-reload'), 0.0015698587127158557)
# ((u'tab-switch', u'tab-new'), 0.0015698587127158557)
# ((u'link_click', u'navigation-form_submit'), 0.0011773940345368916)
# ((u'link_click', u'tab-new'), 0.0011773940345368916)
# ((u'navigation-link', u'tab-switch'), 0.0011773940345368916)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.0011773940345368916)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.0011773940345368916)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.0011773940345368916)
# ((u'link_click', u'tab-close'), 0.0007849293563579278)
# ((u'link_click', u'tab-search'), 0.0007849293563579278)
# ((u'navigation-link-forward_back', u'navigation-link-forward_back'), 0.0007849293563579278)
# ((u'navigation-omni_url', u'navigation-link'), 0.0007849293563579278)
# ((u'navigation-omni_url', u'tab-switch'), 0.0007849293563579278)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.0007849293563579278)
# ((u'tab-loaded', u'navigation-reload'), 0.0007849293563579278)
# ((u'tab-new-switch', u'tab-open-in-new'), 0.0007849293563579278)
# ((u'tab-new-switch', u'tab-switch'), 0.0007849293563579278)
# ((u'tab-open-in-new', u'link_click'), 0.0007849293563579278)
# ((u'tab-search', u'navigation-link'), 0.0007849293563579278)
# ((u'tab-switch', u'tab-search'), 0.0007849293563579278)
# ((u'form_submit', u'link_click'), 0.0003924646781789639)
# ((u'form_submit', u'navigation-link'), 0.0003924646781789639)
# ((u'link_click', u'form_submit'), 0.0003924646781789639)
# ((u'navigation-form_submit', u'link_click'), 0.0003924646781789639)
# ((u'navigation-form_submit', u'navigation-reload'), 0.0003924646781789639)
# ((u'navigation-link', u'navigation-link'), 0.0003924646781789639)
# ((u'navigation-link', u'tab-open-in-new'), 0.0003924646781789639)
# ((u'navigation-link-forward_back', u'link_click'), 0.0003924646781789639)
# ((u'navigation-link-forward_back', u'tab-switch'), 0.0003924646781789639)
# ((u'navigation-start_page', u'tab-loaded'), 0.0003924646781789639)
# ((u'tab-close', u'navigation-link'), 0.0003924646781789639)
# ((u'tab-close', u'tab-loaded'), 0.0003924646781789639)
# ((u'tab-close-switch', u'navigation-manual_subframe'), 0.0003924646781789639)
# ((u'tab-close-switch', u'navigation-start_page'), 0.0003924646781789639)
# ((u'tab-close-switch', u'tab-open-in-new'), 0.0003924646781789639)
# ((u'tab-close-switch', u'tab-search'), 0.0003924646781789639)
# ((u'tab-loaded', u'navigation-omni_url'), 0.0003924646781789639)
# ((u'tab-new-switch', u'tab-loaded'), 0.0003924646781789639)
# ((u'tab-switch', u'navigation-form_submit'), 0.0003924646781789639)
# ((u'tab-switch', u'navigation-link-forward_back'), 0.0003924646781789639)
# ((u'tab-switch', u'tab-open-in-new'), 0.0003924646781789639)
# ((u'navigation-link', u'tab-loaded'), 0.18245050829320492)
# ((u'link_click', u'navigation-link'), 0.1658640984483681)
# ((u'tab-loaded', u'link_click'), 0.1653290529695024)
# ((u'tab-close', u'tab-close-switch'), 0.03584804708400214)
# ((u'navigation-form_submit', u'tab-loaded'), 0.03424291064740503)
# ((u'form_submit', u'navigation-form_submit'), 0.03210272873194221)
# ((u'link_click', u'link_click'), 0.021936864633493848)
# ((u'tab-loaded', u'form_submit'), 0.021401819154628143)
# ((u'tab-loaded', u'tab-open-in-new'), 0.016051364365971106)
# ((u'tab-new', u'tab-new-switch'), 0.016051364365971106)
# ((u'tab-open-in-new', u'navigation-link'), 0.0149812734082397)
# ((u'tab-close-switch', u'tab-close'), 0.014446227929373997)
# ((u'tab-loaded', u'tab-switch'), 0.012306046013911182)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.012306046013911182)
# ((u'tab-replaced', u'tab-replace-switch'), 0.010700909577314071)
# ((u'tab-loaded', u'navigation-link'), 0.010165864098448368)
# ((u'tab-loaded', u'tab-loaded'), 0.010165864098448368)
# ((u'tab-search', u'tab-loaded'), 0.010165864098448368)
# ((u'link_click', u'tab-close'), 0.009630818619582664)
# ((u'tab-loaded', u'tab-close'), 0.00909577314071696)
# ((u'tab-loaded', u'tab-new'), 0.00909577314071696)
# ((u'tab-switch', u'link_click'), 0.008560727661851257)
# ((u'navigation-link', u'link_click'), 0.008025682182985553)
# ((u'tab-replace-switch', u'tab-search'), 0.008025682182985553)
# ((u'tab-switch', u'tab-switch'), 0.008025682182985553)
# ((u'tab-close-switch', u'link_click'), 0.00749063670411985)
# ((u'link_click', u'tab-loaded'), 0.006955591225254147)
# ((u'tab-close-switch', u'tab-switch'), 0.006955591225254147)
# ((u'navigation-omni_url', u'navigation-omni_query'), 0.006420545746388443)
# ((u'navigation-omni_url', u'tab-loaded'), 0.006420545746388443)
# ((u'tab-switch', u'form_submit'), 0.006420545746388443)
# ((u'navigation-omni_query', u'tab-replaced'), 0.005885500267522739)
# ((u'navigation-omni_query', u'navigation-omni_url'), 0.005350454788657036)
# ((u'tab-search', u'navigation-omni_query'), 0.005350454788657036)
# ((u'navigation-omni_query', u'tab-loaded'), 0.004815409309791332)
# ((u'tab-loaded', u'tab-search'), 0.004815409309791332)
# ((u'tab-close-switch', u'tab-new'), 0.004280363830925628)
# ((u'link_click', u'tab-switch'), 0.003745318352059925)
# ((u'navigation-link', u'navigation-link'), 0.003745318352059925)
# ((u'navigation-omni_url', u'navigation-omni_url'), 0.003745318352059925)
# ((u'navigation-link', u'tab-open-in-new'), 0.0032102728731942215)
# ((u'tab-new-switch', u'navigation-omni_query'), 0.0032102728731942215)
# ((u'tab-switch', u'tab-close'), 0.0032102728731942215)
# ((u'link_click', u'tab-replaced'), 0.002675227394328518)
# ((u'tab-open-in-new', u'tab-loaded'), 0.002675227394328518)
# ((u'tab-open-in-new', u'tab-switch'), 0.002675227394328518)
# ((u'tab-switch', u'navigation-link'), 0.002675227394328518)
# ((u'tab-switch', u'tab-loaded'), 0.002675227394328518)
# ((u'navigation-omni_url', u'tab-replaced'), 0.002140181915462814)
# ((u'navigation-reload', u'tab-loaded'), 0.002140181915462814)
# ((u'tab-close-switch', u'form_submit'), 0.002140181915462814)
# ((u'tab-loaded', u'navigation-omni_query'), 0.002140181915462814)
# ((u'tab-switch', u'navigation-reload'), 0.002140181915462814)
# ((u'link_click', u'tab-open-in-new'), 0.0016051364365971107)
# ((u'tab-loaded', u'navigation-omni_url'), 0.0016051364365971107)
# ((u'tab-open-in-new', u'link_click'), 0.0016051364365971107)
# ((u'link_click', u'form_submit'), 0.001070090957731407)
# ((u'link_click', u'navigation-form_submit'), 0.001070090957731407)
# ((u'navigation-link', u'tab-switch'), 0.001070090957731407)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.001070090957731407)
# ((u'navigation-omni_query', u'tab-search'), 0.001070090957731407)
# ((u'navigation-omni_url', u'form_submit'), 0.001070090957731407)
# ((u'navigation-omni_url', u'tab-search'), 0.001070090957731407)
# ((u'tab-close', u'tab-close'), 0.001070090957731407)
# ((u'tab-loaded', u'navigation-form_submit'), 0.001070090957731407)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.001070090957731407)
# ((u'tab-open-in-new', u'tab-open-in-new'), 0.001070090957731407)
# ((u'tab-replace-switch', u'form_submit'), 0.001070090957731407)
# ((u'tab-switch', u'navigation-omni_query'), 0.001070090957731407)
# ((u'tab-switch', u'tab-new'), 0.001070090957731407)
# ((u'form_submit', u'form_submit'), 0.0005350454788657035)
# ((u'form_submit', u'navigation-link'), 0.0005350454788657035)
# ((u'form_submit', u'tab-loaded'), 0.0005350454788657035)
# ((u'link_click', u'tab-search'), 0.0005350454788657035)
# ((u'navigation-form_submit', u'navigation-link'), 0.0005350454788657035)
# ((u'navigation-form_submit', u'tab-switch'), 0.0005350454788657035)
# ((u'navigation-link', u'tab-close'), 0.0005350454788657035)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.0005350454788657035)
# ((u'navigation-omni_query', u'link_click'), 0.0005350454788657035)
# ((u'navigation-omni_query', u'tab-new'), 0.0005350454788657035)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.0005350454788657035)
# ((u'navigation-omni_url', u'link_click'), 0.0005350454788657035)
# ((u'navigation-omni_url', u'navigation-form_submit'), 0.0005350454788657035)
# ((u'navigation-omni_url', u'tab-close'), 0.0005350454788657035)
# ((u'navigation-omni_url', u'tab-switch'), 0.0005350454788657035)
# ((u'navigation-reload', u'navigation-reload'), 0.0005350454788657035)
# ((u'navigation-reload', u'tab-switch'), 0.0005350454788657035)
# ((u'tab-close', u'link_click'), 0.0005350454788657035)
# ((u'tab-close', u'tab-new'), 0.0005350454788657035)
# ((u'tab-close', u'tab-open-in-new'), 0.0005350454788657035)
# ((u'tab-close', u'tab-search'), 0.0005350454788657035)
# ((u'tab-close-switch', u'tab-loaded'), 0.0005350454788657035)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.0005350454788657035)
# ((u'tab-loaded', u'navigation-reload'), 0.0005350454788657035)
# ((u'tab-new-switch', u'tab-search'), 0.0005350454788657035)
# ((u'tab-replace-switch', u'link_click'), 0.0005350454788657035)
# ((u'tab-replace-switch', u'tab-close'), 0.0005350454788657035)
# ((u'tab-replace-switch', u'tab-new'), 0.0005350454788657035)
# ((u'tab-search', u'navigation-link'), 0.0005350454788657035)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.0005350454788657035)
# ((u'tab-switch', u'navigation-form_submit'), 0.0005350454788657035)
# ((u'tab-switch', u'tab-open-in-new'), 0.0005350454788657035)
# ((u'tab-loaded', u'tab-loaded'), 0.10158812359744519)
# ((u'tab-close', u'tab-close-switch'), 0.07931986880718107)
# ((u'tab-new', u'tab-new-switch'), 0.05765579147246677)
# ((u'navigation-link', u'tab-loaded'), 0.05696530295183842)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.05696530295183842)
# ((u'tab-loaded', u'link_click'), 0.05567063697566028)
# ((u'tab-loaded', u'tab-close'), 0.04091144484722942)
# ((u'tab-close-switch', u'tab-new'), 0.030726739167961332)
# ((u'navigation-omni_url', u'tab-loaded'), 0.02900051786639047)
# ((u'link_click', u'navigation-link'), 0.0280510961505265)
# ((u'navigation-omni_url', u'navigation-omni_url'), 0.027964785085447953)
# ((u'tab-search', u'tab-loaded'), 0.026929052304505437)
# ((u'navigation-omni_url', u'navigation-omni_query'), 0.026670119109269808)
# ((u'tab-replaced', u'tab-replace-switch'), 0.024857586742620404)
# ((u'tab-close-switch', u'tab-close'), 0.0236492318315208)
# ((u'tab-replace-switch', u'tab-search'), 0.02028310029345762)
# ((u'navigation-omni_query', u'tab-replaced'), 0.020110478163300534)
# ((u'tab-loaded', u'tab-new'), 0.018384256861729675)
# ((u'link_click', u'tab-open-in-new'), 0.01579492490937338)
# ((u'link_click', u'tab-loaded'), 0.012860348696702916)
# ((u'navigation-form_submit', u'tab-loaded'), 0.012860348696702916)
# ((u'tab-loaded', u'navigation-link'), 0.012256171241153116)
# ((u'tab-switch', u'tab-switch'), 0.011910926980838944)
# ((u'tab-search', u'navigation-link'), 0.008803728638011392)
# ((u'tab-open-in-new', u'navigation-link'), 0.008285862247540134)
# ((u'tab-close-switch', u'tab-switch'), 0.008113240117383048)
# ((u'tab-loaded', u'tab-search'), 0.00785430692214742)
# ((u'tab-close-switch', u'tab-loaded'), 0.007681684791990333)
# ((u'tab-loaded', u'tab-switch'), 0.0075090626618332474)
# ((u'tab-open-in-new', u'tab-search'), 0.0075090626618332474)
# ((u'tab-loaded', u'form_submit'), 0.007422751596754704)
# ((u'link_click', u'link_click'), 0.0072501294665976174)
# ((u'form_submit', u'navigation-form_submit'), 0.006991196271361988)
# ((u'tab-switch', u'tab-close'), 0.006991196271361988)
# ((u'navigation-reload', u'tab-loaded'), 0.006645952011047816)
# ((u'navigation-omni_query', u'navigation-omni_url'), 0.0060417745554980145)
# ((u'tab-open-in-new', u'tab-switch'), 0.005955463490419472)
# ((u'tab-switch', u'tab-loaded'), 0.004919730709476955)
# ((u'navigation-omni_url', u'tab-close'), 0.004660797514241326)
# ((u'tab-loaded', u'tab-open-in-new'), 0.004401864319005696)
# ((u'tab-loaded', u'navigation-omni_url'), 0.004229242188848611)
# ((u'tab-switch', u'navigation-link'), 0.004142931123770067)
# ((u'navigation-omni_url', u'tab-replaced'), 0.004056620058691524)
# ((u'tab-close-switch', u'link_click'), 0.004056620058691524)
# ((u'tab-loaded', u'navigation-reload'), 0.0039703089936129815)
# ((u'link_click', u'navigation-form_submit'), 0.0036250647332988087)
# ((u'navigation-link', u'navigation-link'), 0.0033661315380631796)
# ((u'tab-switch', u'tab-new'), 0.0031935094079060936)
# ((u'tab-switch', u'link_click'), 0.0029345762126704645)
# ((u'navigation-link', u'link_click'), 0.0021577766269635767)
# ((u'navigation-reload', u'navigation-reload'), 0.0021577766269635767)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.0019851544968064907)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.0019851544968064907)
# ((u'tab-replace-switch', u'tab-loaded'), 0.0018988434317279475)
# ((u'navigation-link', u'tab-switch'), 0.0018125323666494044)
# ((u'link_click', u'tab-search'), 0.0016399102364923184)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.0015535991714137752)
# ((u'tab-close-switch', u'tab-open-in-new'), 0.0015535991714137752)
# ((u'tab-loaded', u'navigation-omni_query'), 0.0015535991714137752)
# ((u'link_click', u'tab-close'), 0.0014672881063352323)
# ((u'navigation-link', u'tab-close'), 0.0014672881063352323)
# ((u'link_click', u'tab-new'), 0.001294665976178146)
# ((u'navigation-omni_query', u'tab-loaded'), 0.001294665976178146)
# ((u'tab-loaded', u'navigation-form_submit'), 0.001294665976178146)
# ((u'navigation-omni_url', u'tab-new'), 0.001208354911099603)
# ((u'tab-close', u'navigation-omni_url'), 0.001208354911099603)
# ((u'navigation-omni_query', u'tab-close'), 0.00112204384602106)
# ((u'tab-replace-switch', u'tab-close'), 0.00112204384602106)
# ((u'tab-switch', u'navigation-reload'), 0.00112204384602106)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.0010357327809425167)
# ((u'navigation-omni_url', u'link_click'), 0.0010357327809425167)
# ((u'tab-close-switch', u'navigation-reload'), 0.0010357327809425167)
# ((u'tab-search', u'navigation-omni_query'), 0.0010357327809425167)
# ((u'tab-close-switch', u'navigation-link'), 0.0009494217158639738)
# ((u'navigation-omni_url', u'navigation-link'), 0.0008631106507854307)
# ((u'navigation-omni_url', u'tab-switch'), 0.0007767995857068876)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.0007767995857068876)
# ((u'link_click', u'tab-switch'), 0.0006904885206283445)
# ((u'navigation-omni_query', u'tab-new'), 0.0006904885206283445)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.0006904885206283445)
# ((u'tab-open-in-new', u'tab-loaded'), 0.0006904885206283445)
# ((u'tab-search', u'navigation-reload'), 0.0006904885206283445)
# ((u'form_submit', u'tab-loaded'), 0.0006041774555498015)
# ((u'navigation-omni_query', u'tab-search'), 0.0006041774555498015)
# ((u'navigation-omni_url', u'tab-search'), 0.0006041774555498015)
# ((u'tab-replace-switch', u'link_click'), 0.0006041774555498015)
# ((u'tab-replace-switch', u'tab-new'), 0.0006041774555498015)
# ((u'tab-switch', u'navigation-form_submit'), 0.0006041774555498015)
# ((u'link_click', u'navigation-manual_subframe'), 0.0005178663904712584)
# ((u'navigation-link', u'tab-new'), 0.0005178663904712584)
# ((u'navigation-link', u'tab-search'), 0.0005178663904712584)
# ((u'tab-search', u'navigation-form_submit'), 0.0005178663904712584)
# ((u'form_submit', u'tab-search'), 0.00043155532539271535)
# ((u'tab-switch', u'tab-search'), 0.00043155532539271535)
# ((u'form_submit', u'tab-new'), 0.00034524426031417227)
# ((u'link_click', u'form_submit'), 0.00034524426031417227)
# ((u'link_click', u'tab-replaced'), 0.00034524426031417227)
# ((u'tab-close', u'tab-new'), 0.00034524426031417227)
# ((u'tab-close-switch', u'form_submit'), 0.00034524426031417227)
# ((u'tab-close-switch', u'tab-search'), 0.00034524426031417227)
# ((u'tab-loaded', u'tab-replaced'), 0.00034524426031417227)
# ((u'tab-new-switch', u'tab-close'), 0.00034524426031417227)
# ((u'tab-switch', u'form_submit'), 0.00034524426031417227)
# ((u'tab-switch', u'navigation-omni_query'), 0.00034524426031417227)
# ((u'navigation-link', u'tab-open-in-new'), 0.0002589331952356292)
# ((u'tab-close', u'navigation-omni_query'), 0.0002589331952356292)
# ((u'tab-close', u'tab-close'), 0.0002589331952356292)
# ((u'tab-close', u'tab-loaded'), 0.0002589331952356292)
# ((u'tab-close-switch', u'navigation-manual_subframe'), 0.0002589331952356292)
# ((u'tab-replace-switch', u'form_submit'), 0.0002589331952356292)
# ((u'form_submit', u'navigation-link'), 0.00017262213015708613)
# ((u'form_submit', u'tab-switch'), 0.00017262213015708613)
# ((u'link_click', u'navigation-reload'), 0.00017262213015708613)
# ((u'navigation-form_submit', u'link_click'), 0.00017262213015708613)
# ((u'navigation-link', u'navigation-omni_url'), 0.00017262213015708613)
# ((u'navigation-omni_query', u'tab-switch'), 0.00017262213015708613)
# ((u'navigation-omni_url', u'tab-open-in-new'), 0.00017262213015708613)
# ((u'navigation-reload', u'navigation-omni_url'), 0.00017262213015708613)
# ((u'navigation-reload', u'tab-new'), 0.00017262213015708613)
# ((u'tab-close', u'tab-open-in-new'), 0.00017262213015708613)
# ((u'tab-close-switch', u'navigation-link-forward_back'), 0.00017262213015708613)
# ((u'tab-close-switch', u'navigation-omni_query'), 0.00017262213015708613)
# ((u'tab-close-switch', u'navigation-omni_url'), 0.00017262213015708613)
# ((u'tab-new-switch', u'navigation-link'), 0.00017262213015708613)
# ((u'tab-switch', u'tab-open-in-new'), 0.00017262213015708613)
# ((u'form_submit', u'navigation-omni_query'), 8.631106507854307e-05)
# ((u'navigation-form_submit', u'navigation-link'), 8.631106507854307e-05)
# ((u'navigation-form_submit', u'tab-new'), 8.631106507854307e-05)
# ((u'navigation-link', u'navigation-omni_query'), 8.631106507854307e-05)
# ((u'navigation-omni_query', u'navigation-form_submit'), 8.631106507854307e-05)
# ((u'navigation-omni_query', u'navigation-link'), 8.631106507854307e-05)
# ((u'navigation-reload', u'tab-close'), 8.631106507854307e-05)
# ((u'navigation-reload', u'tab-switch'), 8.631106507854307e-05)
# ((u'navigation-start_page', u'tab-loaded'), 8.631106507854307e-05)
# ((u'tab-close', u'form_submit'), 8.631106507854307e-05)
# ((u'tab-close', u'link_click'), 8.631106507854307e-05)
# ((u'tab-close', u'navigation-link'), 8.631106507854307e-05)
# ((u'tab-close', u'navigation-reload'), 8.631106507854307e-05)
# ((u'tab-new-switch', u'navigation-reload'), 8.631106507854307e-05)
# ((u'tab-new-switch', u'tab-new'), 8.631106507854307e-05)
# ((u'tab-open-in-new', u'tab-close'), 8.631106507854307e-05)
# ((u'tab-open-in-new', u'tab-open-in-new'), 8.631106507854307e-05)
# ((u'tab-replace-switch', u'navigation-form_submit'), 8.631106507854307e-05)
# ((u'tab-search', u'link_click'), 8.631106507854307e-05)
# ((u'tab-search', u'navigation-link-forward_back'), 8.631106507854307e-05)
# ((u'tab-search', u'navigation-start_page'), 8.631106507854307e-05)
# ((u'tab-switch', u'navigation-manual_subframe'), 8.631106507854307e-05)
# ((u'tab-switch', u'navigation-omni_url'), 8.631106507854307e-05)
# ((u'navigation-link', u'tab-loaded'), 0.06369426751592357)
# ((u'tab-loaded', u'tab-loaded'), 0.05785562632696391)
# ((u'tab-switch', u'tab-switch'), 0.049893842887473464)
# ((u'tab-loaded', u'link_click'), 0.04777070063694268)
# ((u'tab-close', u'tab-close'), 0.04723991507430998)
# ((u'tab-new', u'tab-new-switch'), 0.04246284501061571)
# ((u'link_click', u'navigation-link'), 0.03662420382165605)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.030254777070063694)
# ((u'tab-open-in-new', u'tab-switch'), 0.030254777070063694)
# ((u'tab-close', u'tab-close-switch'), 0.029723991507430998)
# ((u'navigation-form_submit', u'tab-loaded'), 0.028662420382165606)
# ((u'tab-loaded', u'tab-switch'), 0.026008492569002124)
# ((u'tab-switch', u'tab-close'), 0.026008492569002124)
# ((u'link_click', u'link_click'), 0.02388535031847134)
# ((u'tab-switch', u'navigation-link'), 0.02335456475583864)
# ((u'tab-switch', u'link_click'), 0.018577494692144373)
# ((u'tab-loaded', u'navigation-form_submit'), 0.014331210191082803)
# ((u'tab-loaded', u'tab-close'), 0.014331210191082803)
# ((u'link_click', u'tab-loaded'), 0.013800424628450107)
# ((u'tab-close', u'tab-open-in-new'), 0.01326963906581741)
# ((u'tab-close', u'tab-switch'), 0.01326963906581741)
# ((u'tab-close', u'tab-new'), 0.012738853503184714)
# ((u'tab-loaded', u'tab-open-in-new'), 0.012208067940552018)
# ((u'tab-switch', u'tab-loaded'), 0.01167728237791932)
# ((u'navigation-omni_url', u'tab-close'), 0.010615711252653927)
# ((u'tab-loaded', u'navigation-link'), 0.009554140127388535)
# ((u'navigation-link', u'tab-close'), 0.009023354564755838)
# ((u'navigation-omni_query', u'tab-loaded'), 0.009023354564755838)
# ((u'tab-close-switch', u'tab-switch'), 0.008492569002123142)
# ((u'tab-open-in-new', u'navigation-link'), 0.008492569002123142)
# ((u'tab-search', u'navigation-omni_query'), 0.008492569002123142)
# ((u'tab-switch', u'tab-new'), 0.008492569002123142)
# ((u'tab-close-switch', u'tab-close'), 0.007961783439490446)
# ((u'navigation-link', u'tab-switch'), 0.0074309978768577496)
# ((u'navigation-omni_url', u'tab-switch'), 0.0074309978768577496)
# ((u'form_submit', u'navigation-form_submit'), 0.006900212314225053)
# ((u'tab-loaded', u'tab-new'), 0.006900212314225053)
# ((u'tab-switch', u'tab-open-in-new'), 0.006900212314225053)
# ((u'navigation-link', u'tab-open-in-new'), 0.006369426751592357)
# ((u'tab-loaded', u'form_submit'), 0.006369426751592357)
# ((u'tab-search', u'navigation-link'), 0.006369426751592357)
# ((u'tab-search', u'tab-loaded'), 0.00583864118895966)
# ((u'link_click', u'navigation-form_submit'), 0.005307855626326964)
# ((u'link_click', u'tab-open-in-new'), 0.005307855626326964)
# ((u'link_click', u'tab-switch'), 0.005307855626326964)
# ((u'navigation-manual_subframe', u'navigation-manual_subframe'), 0.005307855626326964)
# ((u'tab-open-in-new', u'tab-search'), 0.005307855626326964)
# ((u'navigation-link', u'link_click'), 0.004777070063694267)
# ((u'navigation-link', u'navigation-link'), 0.004777070063694267)
# ((u'tab-close', u'navigation-link'), 0.004777070063694267)
# ((u'tab-loaded', u'tab-search'), 0.004777070063694267)
# ((u'navigation-omni_url', u'navigation-link'), 0.004246284501061571)
# ((u'navigation-omni_url', u'tab-loaded'), 0.004246284501061571)
# ((u'tab-close-switch', u'tab-new'), 0.004246284501061571)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.004246284501061571)
# ((u'tab-open-in-new', u'tab-close'), 0.004246284501061571)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.0037154989384288748)
# ((u'navigation-reload', u'tab-loaded'), 0.0037154989384288748)
# ((u'tab-new-switch', u'tab-switch'), 0.0037154989384288748)
# ((u'link_click', u'tab-new'), 0.0031847133757961785)
# ((u'navigation-omni_url', u'navigation-omni_url'), 0.0031847133757961785)
# ((u'tab-open-in-new', u'tab-open-in-new'), 0.0031847133757961785)
# ((u'tab-switch', u'tab-search'), 0.0031847133757961785)
# ((u'navigation-omni_url', u'tab-search'), 0.002653927813163482)
# ((u'tab-close-switch', u'tab-loaded'), 0.002653927813163482)
# ((u'tab-switch', u'navigation-omni_url'), 0.002653927813163482)
# ((u'navigation-link', u'tab-new'), 0.0021231422505307855)
# ((u'navigation-manual_subframe', u'tab-close'), 0.0021231422505307855)
# ((u'navigation-omni_url', u'tab-open-in-new'), 0.0021231422505307855)
# ((u'tab-close', u'tab-loaded'), 0.0021231422505307855)
# ((u'tab-close-switch', u'tab-open-in-new'), 0.0021231422505307855)
# ((u'tab-loaded', u'navigation-reload'), 0.0021231422505307855)
# ((u'tab-new-switch', u'tab-close'), 0.0021231422505307855)
# ((u'tab-new-switch', u'tab-new'), 0.0021231422505307855)
# ((u'tab-new-switch', u'tab-search'), 0.0021231422505307855)
# ((u'tab-open-in-new', u'tab-new'), 0.0021231422505307855)
# ((u'tab-replaced', u'tab-replace-switch'), 0.0021231422505307855)
# ((u'tab-switch', u'navigation-form_submit'), 0.0021231422505307855)
# ((u'link_click', u'navigation-manual_subframe'), 0.0015923566878980893)
# ((u'navigation-link', u'navigation-manual_subframe'), 0.0015923566878980893)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.0015923566878980893)
# ((u'tab-close-switch', u'link_click'), 0.0015923566878980893)
# ((u'tab-close-switch', u'tab-search'), 0.0015923566878980893)
# ((u'link_click', u'navigation-link-forward_back'), 0.0010615711252653928)
# ((u'link_click', u'tab-replaced'), 0.0010615711252653928)
# ((u'navigation-link', u'tab-replaced'), 0.0010615711252653928)
# ((u'navigation-link-forward_back', u'navigation-link'), 0.0010615711252653928)
# ((u'navigation-reload', u'navigation-reload'), 0.0010615711252653928)
# ((u'navigation-reload', u'tab-close'), 0.0010615711252653928)
# ((u'tab-close', u'navigation-manual_subframe'), 0.0010615711252653928)
# ((u'tab-close', u'navigation-omni_query'), 0.0010615711252653928)
# ((u'tab-close', u'tab-search'), 0.0010615711252653928)
# ((u'tab-close-switch', u'navigation-link'), 0.0010615711252653928)
# ((u'tab-new', u'navigation-reload'), 0.0010615711252653928)
# ((u'tab-new-switch', u'navigation-link'), 0.0010615711252653928)
# ((u'tab-new-switch', u'tab-open-in-new'), 0.0010615711252653928)
# ((u'tab-open-in-new', u'navigation-reload'), 0.0010615711252653928)
# ((u'tab-replace-switch', u'tab-switch'), 0.0010615711252653928)
# ((u'link_click', u'tab-close'), 0.0005307855626326964)
# ((u'link_click', u'tab-close-switch'), 0.0005307855626326964)
# ((u'link_click', u'tab-search'), 0.0005307855626326964)
# ((u'navigation-form_submit', u'link_click'), 0.0005307855626326964)
# ((u'navigation-form_submit', u'navigation-form_submit'), 0.0005307855626326964)
# ((u'navigation-form_submit', u'tab-new'), 0.0005307855626326964)
# ((u'navigation-form_submit', u'tab-open-in-new'), 0.0005307855626326964)
# ((u'navigation-link', u'navigation-form_submit'), 0.0005307855626326964)
# ((u'navigation-link', u'navigation-omni_url'), 0.0005307855626326964)
# ((u'navigation-link-forward_back', u'navigation-manual_subframe'), 0.0005307855626326964)
# ((u'navigation-link-forward_back', u'tab-open-in-new'), 0.0005307855626326964)
# ((u'navigation-link-forward_back', u'tab-switch'), 0.0005307855626326964)
# ((u'navigation-manual_subframe', u'link_click'), 0.0005307855626326964)
# ((u'navigation-manual_subframe', u'navigation-link'), 0.0005307855626326964)
# ((u'navigation-manual_subframe', u'tab-new'), 0.0005307855626326964)
# ((u'navigation-manual_subframe', u'tab-open-in-new'), 0.0005307855626326964)
# ((u'navigation-manual_subframe', u'tab-switch'), 0.0005307855626326964)
# ((u'navigation-omni_query', u'navigation-start_page'), 0.0005307855626326964)
# ((u'navigation-omni_query', u'tab-close'), 0.0005307855626326964)
# ((u'navigation-omni_query', u'tab-switch'), 0.0005307855626326964)
# ((u'navigation-omni_url', u'form_submit'), 0.0005307855626326964)
# ((u'navigation-omni_url', u'link_click'), 0.0005307855626326964)
# ((u'navigation-omni_url', u'navigation-form_submit'), 0.0005307855626326964)
# ((u'navigation-omni_url', u'navigation-manual_subframe'), 0.0005307855626326964)
# ((u'navigation-omni_url', u'navigation-omni_query'), 0.0005307855626326964)
# ((u'navigation-omni_url', u'tab-new'), 0.0005307855626326964)
# ((u'navigation-reload', u'tab-open-in-new'), 0.0005307855626326964)
# ((u'navigation-start_page', u'navigation-omni_query'), 0.0005307855626326964)
# ((u'navigation-start_page', u'tab-close'), 0.0005307855626326964)
# ((u'navigation-start_page', u'tab-open-in-new'), 0.0005307855626326964)
# ((u'tab-close', u'navigation-omni_url'), 0.0005307855626326964)
# ((u'tab-close-switch', u'navigation-form_submit'), 0.0005307855626326964)
# ((u'tab-close-switch', u'navigation-start_page'), 0.0005307855626326964)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.0005307855626326964)
# ((u'tab-loaded', u'navigation-omni_url'), 0.0005307855626326964)
# ((u'tab-loaded', u'tab-close-switch'), 0.0005307855626326964)
# ((u'tab-open-in-new', u'navigation-link-forward_back'), 0.0005307855626326964)
# ((u'tab-replace-switch', u'link_click'), 0.0005307855626326964)
# ((u'tab-replace-switch', u'tab-close'), 0.0005307855626326964)
# ((u'tab-search', u'navigation-reload'), 0.0005307855626326964)
# ((u'tab-switch', u'navigation-link-forward_back'), 0.0005307855626326964)
# ((u'tab-switch', u'navigation-manual_subframe'), 0.0005307855626326964)
# ((u'tab-switch', u'navigation-reload'), 0.0005307855626326964)
# ((u'tab-switch', u'navigation-start_page'), 0.0005307855626326964)
# ((u'navigation-link', u'tab-loaded'), 0.08167281672816729)
# ((u'tab-loaded', u'tab-loaded'), 0.06888068880688807)
# ((u'tab-loaded', u'link_click'), 0.06396063960639606)
# ((u'navigation-form_submit', u'tab-loaded'), 0.05289052890528905)
# ((u'tab-close', u'tab-close-switch'), 0.05141451414514145)
# ((u'link_click', u'navigation-link'), 0.04526445264452644)
# ((u'form_submit', u'navigation-form_submit'), 0.03665436654366544)
# ((u'tab-switch', u'tab-switch'), 0.035916359163591635)
# ((u'tab-loaded', u'form_submit'), 0.034932349323493234)
# ((u'link_click', u'link_click'), 0.024600246002460024)
# ((u'tab-loaded', u'tab-switch'), 0.021648216482164823)
# ((u'tab-open-in-new', u'tab-switch'), 0.01894218942189422)
# ((u'tab-loaded', u'tab-close'), 0.017958179581795818)
# ((u'tab-switch', u'tab-loaded'), 0.017466174661746617)
# ((u'tab-loaded', u'tab-open-in-new'), 0.017220172201722016)
# ((u'tab-switch', u'navigation-link'), 0.017220172201722016)
# ((u'tab-new', u'tab-new-switch'), 0.016974169741697416)
# ((u'link_click', u'tab-loaded'), 0.015990159901599015)
# ((u'tab-loaded', u'navigation-form_submit'), 0.015252152521525215)
# ((u'tab-close-switch', u'tab-close'), 0.015006150061500615)
# ((u'tab-loaded', u'navigation-link'), 0.014760147601476014)
# ((u'tab-open-in-new', u'navigation-link'), 0.014514145141451414)
# ((u'tab-switch', u'tab-close'), 0.014514145141451414)
# ((u'tab-close-switch', u'tab-switch'), 0.013284132841328414)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.012546125461254613)
# ((u'tab-search', u'tab-loaded'), 0.010578105781057811)
# ((u'tab-switch', u'link_click'), 0.008610086100861008)
# ((u'link_click', u'tab-open-in-new'), 0.0076260762607626075)
# ((u'navigation-link', u'tab-switch'), 0.0076260762607626075)
# ((u'tab-search', u'navigation-omni_query'), 0.0076260762607626075)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.006642066420664207)
# ((u'navigation-omni_url', u'tab-loaded'), 0.006642066420664207)
# ((u'tab-loaded', u'tab-new'), 0.0063960639606396065)
# ((u'tab-loaded', u'tab-search'), 0.0063960639606396065)
# ((u'tab-search', u'navigation-link'), 0.0063960639606396065)
# ((u'navigation-omni_query', u'tab-loaded'), 0.006150061500615006)
# ((u'navigation-link', u'navigation-link'), 0.005412054120541206)
# ((u'link_click', u'tab-search'), 0.0051660516605166054)
# ((u'tab-close-switch', u'link_click'), 0.0051660516605166054)
# ((u'tab-replaced', u'tab-replace-switch'), 0.0051660516605166054)
# ((u'link_click', u'tab-switch'), 0.004674046740467405)
# ((u'tab-close-switch', u'tab-loaded'), 0.004674046740467405)
# ((u'tab-close-switch', u'tab-open-in-new'), 0.004674046740467405)
# ((u'tab-open-in-new', u'tab-open-in-new'), 0.004674046740467405)
# ((u'navigation-link', u'tab-close'), 0.004428044280442804)
# ((u'navigation-link', u'tab-open-in-new'), 0.004428044280442804)
# ((u'navigation-omni_url', u'tab-switch'), 0.004428044280442804)
# ((u'navigation-link', u'link_click'), 0.004182041820418204)
# ((u'link_click', u'form_submit'), 0.0039360393603936035)
# ((u'tab-close-switch', u'tab-new'), 0.0039360393603936035)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.0039360393603936035)
# ((u'navigation-omni_query', u'tab-replaced'), 0.0036900369003690036)
# ((u'tab-close', u'tab-close'), 0.0036900369003690036)
# ((u'tab-replace-switch', u'tab-search'), 0.0036900369003690036)
# ((u'tab-switch', u'tab-new'), 0.0036900369003690036)
# ((u'tab-switch', u'tab-search'), 0.0036900369003690036)
# ((u'navigation-omni_url', u'navigation-omni_url'), 0.0031980319803198032)
# ((u'tab-switch', u'tab-open-in-new'), 0.0031980319803198032)
# ((u'link_click', u'tab-close'), 0.0024600246002460025)
# ((u'navigation-reload', u'tab-loaded'), 0.0024600246002460025)
# ((u'tab-loaded', u'navigation-reload'), 0.0024600246002460025)
# ((u'tab-open-in-new', u'link_click'), 0.0024600246002460025)
# ((u'tab-switch', u'navigation-omni_url'), 0.0024600246002460025)
# ((u'navigation-omni_url', u'tab-search'), 0.002214022140221402)
# ((u'form_submit', u'tab-search'), 0.0019680196801968018)
# ((u'link_click', u'tab-new'), 0.0019680196801968018)
# ((u'navigation-form_submit', u'tab-switch'), 0.0019680196801968018)
# ((u'tab-close', u'tab-open-in-new'), 0.0019680196801968018)
# ((u'tab-loaded', u'navigation-omni_url'), 0.0019680196801968018)
# ((u'tab-open-in-new', u'tab-close'), 0.0019680196801968018)
# ((u'tab-search', u'navigation-form_submit'), 0.0019680196801968018)
# ((u'tab-switch', u'navigation-form_submit'), 0.0019680196801968018)
# ((u'navigation-omni_url', u'navigation-omni_query'), 0.0017220172201722018)
# ((u'navigation-omni_url', u'tab-close'), 0.0017220172201722018)
# ((u'link_click', u'tab-replaced'), 0.0014760147601476014)
# ((u'navigation-form_submit', u'navigation-link'), 0.0014760147601476014)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.0014760147601476014)
# ((u'tab-close', u'link_click'), 0.0014760147601476014)
# ((u'tab-close', u'navigation-link'), 0.0014760147601476014)
# ((u'tab-close', u'tab-loaded'), 0.0014760147601476014)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.0014760147601476014)
# ((u'tab-loaded', u'navigation-omni_query'), 0.0014760147601476014)
# ((u'form_submit', u'navigation-link'), 0.0012300123001230013)
# ((u'navigation-link', u'tab-search'), 0.0012300123001230013)
# ((u'navigation-omni_url', u'link_click'), 0.0012300123001230013)
# ((u'tab-close-switch', u'navigation-omni_url'), 0.0012300123001230013)
# ((u'tab-new-switch', u'tab-close'), 0.0012300123001230013)
# ((u'tab-new-switch', u'tab-search'), 0.0012300123001230013)
# ((u'tab-new-switch', u'tab-switch'), 0.0012300123001230013)
# ((u'tab-open-in-new', u'tab-loaded'), 0.0012300123001230013)
# ((u'tab-search', u'navigation-link-forward_back'), 0.0012300123001230013)
# ((u'tab-switch', u'form_submit'), 0.0012300123001230013)
# ((u'form_submit', u'tab-open-in-new'), 0.0009840098400984009)
# ((u'navigation-omni_query', u'tab-switch'), 0.0009840098400984009)
# ((u'tab-close', u'tab-search'), 0.0009840098400984009)
# ((u'tab-close-switch', u'navigation-link'), 0.0009840098400984009)
# ((u'tab-open-in-new', u'tab-search'), 0.0009840098400984009)
# ((u'form_submit', u'link_click'), 0.0007380073800738007)
# ((u'link_click', u'navigation-form_submit'), 0.0007380073800738007)
# ((u'navigation-form_submit', u'link_click'), 0.0007380073800738007)
# ((u'navigation-link', u'navigation-form_submit'), 0.0007380073800738007)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.0007380073800738007)
# ((u'navigation-omni_url', u'navigation-link'), 0.0007380073800738007)
# ((u'tab-close-switch', u'form_submit'), 0.0007380073800738007)
# ((u'tab-close-switch', u'tab-search'), 0.0007380073800738007)
# ((u'tab-replace-switch', u'link_click'), 0.0007380073800738007)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.0007380073800738007)
# ((u'tab-switch', u'navigation-link-forward_back'), 0.0007380073800738007)
# ((u'form_submit', u'form_submit'), 0.0004920049200492004)
# ((u'navigation-form_submit', u'navigation-form_submit'), 0.0004920049200492004)
# ((u'navigation-form_submit', u'tab-new'), 0.0004920049200492004)
# ((u'navigation-omni_query', u'link_click'), 0.0004920049200492004)
# ((u'navigation-omni_query', u'navigation-omni_url'), 0.0004920049200492004)
# ((u'navigation-omni_query', u'tab-close'), 0.0004920049200492004)
# ((u'navigation-omni_url', u'form_submit'), 0.0004920049200492004)
# ((u'navigation-omni_url', u'tab-open-in-new'), 0.0004920049200492004)
# ((u'navigation-start_page', u'navigation-omni_query'), 0.0004920049200492004)
# ((u'navigation-start_page', u'navigation-omni_url'), 0.0004920049200492004)
# ((u'tab-close', u'tab-new'), 0.0004920049200492004)
# ((u'tab-close-switch', u'navigation-link-forward_back'), 0.0004920049200492004)
# ((u'tab-close-switch', u'navigation-omni_query'), 0.0004920049200492004)
# ((u'tab-open-in-new', u'form_submit'), 0.0004920049200492004)
# ((u'tab-replace-switch', u'tab-switch'), 0.0004920049200492004)
# ((u'tab-switch', u'navigation-omni_query'), 0.0004920049200492004)
# ((u'tab-switch', u'navigation-reload'), 0.0004920049200492004)
# ((u'form_submit', u'tab-loaded'), 0.0002460024600246002)
# ((u'form_submit', u'tab-switch'), 0.0002460024600246002)
# ((u'link_click', u'navigation-link-forward_back'), 0.0002460024600246002)
# ((u'link_click', u'navigation-omni_url'), 0.0002460024600246002)
# ((u'link_click', u'navigation-omni_url-forward_back'), 0.0002460024600246002)
# ((u'navigation-link', u'form_submit'), 0.0002460024600246002)
# ((u'navigation-link', u'navigation-link-forward_back'), 0.0002460024600246002)
# ((u'navigation-link-forward_back', u'link_click'), 0.0002460024600246002)
# ((u'navigation-link-forward_back', u'navigation-link-forward_back'), 0.0002460024600246002)
# ((u'navigation-manual_subframe', u'navigation-form_submit'), 0.0002460024600246002)
# ((u'navigation-omni_query', u'tab-search'), 0.0002460024600246002)
# ((u'navigation-omni_url-forward_back', u'tab-close'), 0.0002460024600246002)
# ((u'navigation-omni_url-forward_back', u'tab-switch'), 0.0002460024600246002)
# ((u'navigation-reload', u'navigation-link'), 0.0002460024600246002)
# ((u'navigation-reload', u'navigation-omni_url'), 0.0002460024600246002)
# ((u'navigation-reload', u'tab-switch'), 0.0002460024600246002)
# ((u'tab-close', u'navigation-omni_query'), 0.0002460024600246002)
# ((u'tab-close', u'navigation-reload'), 0.0002460024600246002)
# ((u'tab-close', u'navigation-start_page'), 0.0002460024600246002)
# ((u'tab-close-switch', u'navigation-start_page'), 0.0002460024600246002)
# ((u'tab-loaded', u'navigation-omni_url-forward_back'), 0.0002460024600246002)
# ((u'tab-loaded', u'navigation-start_page'), 0.0002460024600246002)
# ((u'tab-new-switch', u'navigation-link'), 0.0002460024600246002)
# ((u'tab-new-switch', u'navigation-start_page'), 0.0002460024600246002)
# ((u'tab-new-switch', u'tab-loaded'), 0.0002460024600246002)
# ((u'tab-replace-switch', u'navigation-link'), 0.0002460024600246002)
# ((u'tab-switch', u'navigation-manual_subframe'), 0.0002460024600246002)
# ((u'tab-switch', u'tab-close-switch'), 0.0002460024600246002)
# ((u'tab-loaded', u'tab-loaded'), 0.11514778325123153)
# ((u'navigation-link', u'tab-loaded'), 0.09421182266009852)
# ((u'tab-loaded', u'link_click'), 0.07912561576354679)
# ((u'link_click', u'navigation-link'), 0.07543103448275862)
# ((u'tab-switch', u'tab-switch'), 0.06773399014778325)
# ((u'tab-loaded', u'tab-switch'), 0.04710591133004926)
# ((u'navigation-form_submit', u'tab-loaded'), 0.042487684729064036)
# ((u'form_submit', u'navigation-form_submit'), 0.039716748768472906)
# ((u'tab-loaded', u'form_submit'), 0.0332512315270936)
# ((u'tab-search', u'tab-loaded'), 0.025246305418719212)
# ((u'tab-switch', u'tab-loaded'), 0.021551724137931036)
# ((u'tab-close', u'tab-close-switch'), 0.021243842364532018)
# ((u'tab-replaced', u'tab-replace-switch'), 0.017241379310344827)
# ((u'link_click', u'link_click'), 0.016933497536945813)
# ((u'tab-replace-switch', u'tab-search'), 0.0166256157635468)
# ((u'navigation-omni_query', u'tab-replaced'), 0.016317733990147784)
# ((u'tab-new', u'tab-new-switch'), 0.014470443349753694)
# ((u'tab-loaded', u'tab-search'), 0.013546798029556651)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.012623152709359606)
# ((u'tab-new-switch', u'navigation-omni_query'), 0.012007389162561576)
# ((u'tab-switch', u'link_click'), 0.011391625615763547)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.010775862068965518)
# ((u'tab-switch', u'navigation-link'), 0.010775862068965518)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.010160098522167487)
# ((u'tab-open-in-new', u'tab-switch'), 0.009544334975369459)
# ((u'link_click', u'tab-loaded'), 0.009236453201970444)
# ((u'tab-loaded', u'navigation-link'), 0.009236453201970444)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.008928571428571428)
# ((u'tab-close-switch', u'tab-switch'), 0.008620689655172414)
# ((u'tab-loaded', u'tab-close'), 0.008620689655172414)
# ((u'tab-loaded', u'tab-new'), 0.007389162561576354)
# ((u'tab-switch', u'form_submit'), 0.007389162561576354)
# ((u'link_click', u'tab-open-in-new'), 0.00646551724137931)
# ((u'tab-switch', u'tab-close'), 0.006157635467980296)
# ((u'tab-switch', u'tab-new'), 0.006157635467980296)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.005233990147783251)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.005233990147783251)
# ((u'tab-loaded', u'navigation-omni_query'), 0.0049261083743842365)
# ((u'tab-close-switch', u'tab-close'), 0.004618226600985222)
# ((u'tab-loaded', u'tab-open-in-new'), 0.0033866995073891628)
# ((u'navigation-link', u'link_click'), 0.003078817733990148)
# ((u'tab-close-switch', u'tab-loaded'), 0.003078817733990148)
# ((u'navigation-omni_url', u'tab-loaded'), 0.002770935960591133)
# ((u'tab-search', u'navigation-form_submit'), 0.0021551724137931034)
# ((u'tab-switch', u'tab-search'), 0.0021551724137931034)
# ((u'link_click', u'tab-switch'), 0.0018472906403940886)
# ((u'tab-switch', u'navigation-manual_subframe'), 0.0018472906403940886)
# ((u'tab-switch', u'navigation-omni_query'), 0.0018472906403940886)
# ((u'navigation-reload', u'tab-loaded'), 0.001539408866995074)
# ((u'tab-close-switch', u'link_click'), 0.001539408866995074)
# ((u'tab-replaced', u'tab-switch'), 0.001539408866995074)
# ((u'tab-search', u'navigation-link'), 0.001539408866995074)
# ((u'tab-search', u'navigation-link-forward_back'), 0.001539408866995074)
# ((u'form_submit', u'tab-search'), 0.0012315270935960591)
# ((u'link_click', u'form_submit'), 0.0012315270935960591)
# ((u'link_click', u'tab-search'), 0.0012315270935960591)
# ((u'navigation-link', u'navigation-link'), 0.0012315270935960591)
# ((u'navigation-omni_query', u'navigation-omni_url'), 0.0012315270935960591)
# ((u'tab-close', u'tab-close'), 0.0012315270935960591)
# ((u'tab-close', u'tab-switch'), 0.0012315270935960591)
# ((u'tab-loaded', u'navigation-omni_url'), 0.0012315270935960591)
# ((u'tab-loaded', u'navigation-reload'), 0.0012315270935960591)
# ((u'tab-open-in-new', u'navigation-link'), 0.0012315270935960591)
# ((u'form_submit', u'form_submit'), 0.0009236453201970443)
# ((u'form_submit', u'tab-loaded'), 0.0009236453201970443)
# ((u'navigation-omni_query', u'tab-close'), 0.0009236453201970443)
# ((u'tab-close-switch', u'navigation-manual_subframe'), 0.0009236453201970443)
# ((u'tab-close-switch', u'tab-new'), 0.0009236453201970443)
# ((u'tab-close-switch', u'tab-open-in-new'), 0.0009236453201970443)
# ((u'tab-loaded', u'navigation-form_submit'), 0.0009236453201970443)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.0009236453201970443)
# ((u'tab-new-switch', u'tab-switch'), 0.0009236453201970443)
# ((u'tab-open-in-new', u'link_click'), 0.0009236453201970443)
# ((u'tab-switch', u'tab-open-in-new'), 0.0009236453201970443)
# ((u'link_click', u'tab-close'), 0.0006157635467980296)
# ((u'link_click', u'tab-replaced'), 0.0006157635467980296)
# ((u'navigation-link', u'tab-close'), 0.0006157635467980296)
# ((u'navigation-link', u'tab-search'), 0.0006157635467980296)
# ((u'tab-loaded', u'tab-replaced'), 0.0006157635467980296)
# ((u'tab-new-switch', u'tab-replaced'), 0.0006157635467980296)
# ((u'tab-switch', u'navigation-link-forward_back'), 0.0006157635467980296)
# ((u'tab-switch', u'tab-replaced'), 0.0006157635467980296)
# ((u'form_submit', u'navigation-link'), 0.0003078817733990148)
# ((u'form_submit', u'tab-close'), 0.0003078817733990148)
# ((u'link_click', u'navigation-omni_query'), 0.0003078817733990148)
# ((u'navigation-form_submit', u'tab-switch'), 0.0003078817733990148)
# ((u'navigation-link', u'tab-open-in-new'), 0.0003078817733990148)
# ((u'navigation-link', u'tab-switch'), 0.0003078817733990148)
# ((u'navigation-link-forward_back', u'link_click'), 0.0003078817733990148)
# ((u'navigation-manual_subframe', u'navigation-link'), 0.0003078817733990148)
# ((u'navigation-manual_subframe', u'navigation-manual_subframe'), 0.0003078817733990148)
# ((u'navigation-manual_subframe', u'tab-switch'), 0.0003078817733990148)
# ((u'navigation-omni_query', u'form_submit'), 0.0003078817733990148)
# ((u'navigation-omni_query', u'link_click'), 0.0003078817733990148)
# ((u'navigation-omni_query', u'tab-loaded'), 0.0003078817733990148)
# ((u'navigation-omni_query', u'tab-search'), 0.0003078817733990148)
# ((u'navigation-omni_query', u'tab-switch'), 0.0003078817733990148)
# ((u'navigation-omni_url', u'navigation-omni_query'), 0.0003078817733990148)
# ((u'navigation-omni_url', u'tab-replaced'), 0.0003078817733990148)
# ((u'tab-close', u'tab-loaded'), 0.0003078817733990148)
# ((u'tab-close-switch', u'form_submit'), 0.0003078817733990148)
# ((u'tab-close-switch', u'navigation-omni_query'), 0.0003078817733990148)
# ((u'tab-close-switch', u'tab-search'), 0.0003078817733990148)
# ((u'tab-loaded', u'tab-new-switch'), 0.0003078817733990148)
# ((u'tab-new-switch', u'navigation-link'), 0.0003078817733990148)
# ((u'tab-new-switch', u'tab-close'), 0.0003078817733990148)
# ((u'tab-open-in-new', u'tab-close'), 0.0003078817733990148)
# ((u'tab-replace-switch', u'link_click'), 0.0003078817733990148)
# ((u'tab-replace-switch', u'tab-close'), 0.0003078817733990148)
# ((u'tab-replaced', u'navigation-manual_subframe'), 0.0003078817733990148)
# ((u'tab-search', u'navigation-omni_query'), 0.0003078817733990148)
# ((u'tab-switch', u'navigation-reload'), 0.0003078817733990148)
# ((u'tab-switch', u'tab-close-switch'), 0.0003078817733990148)
# ((u'tab-switch', u'tab-new-switch'), 0.0003078817733990148)
# ((u'navigation-link', u'tab-loaded'), 0.0779892973067813)
# ((u'tab-loaded', u'link_click'), 0.06842705500482499)
# ((u'navigation-form_submit', u'tab-loaded'), 0.0679006930432494)
# ((u'link_click', u'navigation-link'), 0.060443898587595406)
# ((u'form_submit', u'navigation-form_submit'), 0.05649618387577858)
# ((u'tab-loaded', u'tab-loaded'), 0.05553118694622335)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.049916659356083866)
# ((u'tab-loaded', u'form_submit'), 0.046758487586630405)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.044653039740328096)
# ...
# ((u'link_click', u'navigation-omni_query'), 0.0011547344110854503)
# ((u'link_click', u'navigation-omni_url'), 0.0011547344110854503)
# ((u'link_click', u'tab-new-switch'), 0.0011547344110854503)
# ((u'navigation-form_submit', u'navigation-form_submit'), 0.0011547344110854503)
# ((u'navigation-form_submit', u'navigation-link'), 0.0011547344110854503)
# ((u'navigation-form_submit', u'tab-switch'), 0.0011547344110854503)
# ((u'navigation-link', u'form_submit'), 0.0011547344110854503)
# ((u'navigation-link', u'navigation-form_submit'), 0.0011547344110854503)
# ((u'navigation-link', u'navigation-reload'), 0.0011547344110854503)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.0011547344110854503)
# ((u'navigation-omni_query', u'tab-switch'), 0.0011547344110854503)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.0011547344110854503)
# ((u'navigation-omni_url', u'navigation-link'), 0.0011547344110854503)
# ((u'navigation-omni_url', u'tab-switch'), 0.0011547344110854503)
# ((u'navigation-reload', u'navigation-reload'), 0.0011547344110854503)
# ((u'navigation-reload', u'tab-new'), 0.0011547344110854503)
# ((u'navigation-start_page', u'navigation-omni_query'), 0.0011547344110854503)
# ((u'navigation-start_page', u'tab-loaded'), 0.0011547344110854503)
# ((u'tab-close', u'navigation-start_page'), 0.0011547344110854503)
# ((u'tab-close', u'tab-switch'), 0.0011547344110854503)
# ((u'tab-close-switch', u'link_click'), 0.0011547344110854503)
# ((u'tab-close-switch', u'navigation-link'), 0.0011547344110854503)
# ((u'tab-close-switch', u'navigation-omni_query'), 0.0011547344110854503)
# ((u'tab-close-switch', u'navigation-omni_url'), 0.0011547344110854503)
# ((u'tab-loaded', u'navigation-omni_url'), 0.0011547344110854503)
# ((u'tab-loaded', u'navigation-start_page'), 0.0011547344110854503)
# ((u'tab-open-in-new', u'tab-close'), 0.0011547344110854503)
# ((u'tab-replace-switch', u'form_submit'), 0.0011547344110854503)
# ((u'tab-replace-switch', u'link_click'), 0.0011547344110854503)
# ((u'tab-replace-switch', u'navigation-form_submit'), 0.0011547344110854503)
# ((u'tab-replace-switch', u'navigation-link'), 0.0011547344110854503)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.0011547344110854503)
# ((u'tab-switch', u'navigation-link-forward_back'), 0.0011547344110854503)
# ((u'tab-switch', u'tab-open-in-new'), 0.0011547344110854503)
# ((u'tab-switch', u'tab-search'), 0.0011547344110854503)
# ((u'navigation-link', u'tab-loaded'), 0.15977175463623394)
# ((u'link_click', u'navigation-link'), 0.1355206847360913)
# ((u'tab-loaded', u'link_click'), 0.11697574893009986)
# ((u'tab-loaded', u'tab-switch'), 0.03281027104136947)
# ((u'tab-switch', u'link_click'), 0.029957203994293864)
# ((u'tab-close', u'tab-close-switch'), 0.028530670470756064)
# ((u'tab-loaded', u'navigation-link'), 0.02282453637660485)
# ((u'tab-new', u'tab-new-switch'), 0.02282453637660485)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.02282453637660485)
# ((u'navigation-manual_subframe', u'navigation-manual_subframe'), 0.021398002853067047)
# ((u'navigation-form_submit', u'tab-loaded'), 0.018544935805991442)
# ((u'tab-search', u'tab-loaded'), 0.018544935805991442)
# ((u'form_submit', u'navigation-form_submit'), 0.017118402282453638)
# ((u'tab-loaded', u'form_submit'), 0.017118402282453638)
# ((u'tab-loaded', u'tab-search'), 0.017118402282453638)
# ((u'navigation-reload', u'tab-loaded'), 0.015691868758915834)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.014265335235378032)
# ((u'navigation-omni_url', u'navigation-omni_query'), 0.014265335235378032)
# ((u'tab-loaded', u'tab-loaded'), 0.014265335235378032)
# ((u'tab-replaced', u'tab-replace-switch'), 0.014265335235378032)
# ((u'tab-loaded', u'tab-close'), 0.012838801711840228)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.011412268188302425)
# ((u'navigation-omni_query', u'tab-replaced'), 0.011412268188302425)
# ((u'link_click', u'link_click'), 0.009985734664764621)
# ((u'tab-close-switch', u'tab-new'), 0.008559201141226819)
# ((u'tab-loaded', u'tab-new'), 0.008559201141226819)
# ((u'tab-open-in-new', u'tab-switch'), 0.008559201141226819)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.007132667617689016)
# ((u'tab-replace-switch', u'tab-search'), 0.007132667617689016)
# ((u'tab-search', u'navigation-link-forward_back'), 0.007132667617689016)
# ((u'tab-switch', u'navigation-reload'), 0.007132667617689016)
# ((u'link_click', u'tab-open-in-new'), 0.005706134094151213)
# ((u'link_click', u'tab-switch'), 0.005706134094151213)
# ((u'navigation-link', u'navigation-link'), 0.005706134094151213)
# ((u'navigation-omni_url', u'tab-loaded'), 0.005706134094151213)
# ((u'tab-close-switch', u'link_click'), 0.005706134094151213)
# ((u'tab-loaded', u'navigation-reload'), 0.005706134094151213)
# ((u'tab-loaded', u'tab-open-in-new'), 0.005706134094151213)
# ((u'tab-switch', u'tab-close'), 0.005706134094151213)
# ((u'tab-switch', u'tab-switch'), 0.005706134094151213)
# ((u'navigation-omni_url', u'tab-close'), 0.0042796005706134095)
# ((u'tab-close', u'tab-new'), 0.0042796005706134095)
# ((u'tab-close-switch', u'tab-switch'), 0.0042796005706134095)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.0042796005706134095)
# ((u'tab-switch', u'navigation-link'), 0.0042796005706134095)
# ((u'link_click', u'navigation-link-forward_back'), 0.0028530670470756064)
# ((u'link_click', u'tab-loaded'), 0.0028530670470756064)
# ((u'link_click', u'tab-replaced'), 0.0028530670470756064)
# ((u'navigation-link', u'link_click'), 0.0028530670470756064)
# ((u'navigation-link', u'tab-close'), 0.0028530670470756064)
# ((u'navigation-omni_query', u'tab-switch'), 0.0028530670470756064)
# ((u'navigation-omni_url', u'tab-switch'), 0.0028530670470756064)
# ((u'tab-close', u'tab-close'), 0.0028530670470756064)
# ((u'tab-close-switch', u'tab-close'), 0.0028530670470756064)
# ((u'tab-replace-switch', u'navigation-link'), 0.0028530670470756064)
# ((u'tab-replace-switch', u'navigation-omni_query'), 0.0028530670470756064)
# ((u'tab-switch', u'navigation-omni_query'), 0.0028530670470756064)
# ((u'tab-switch', u'tab-loaded'), 0.0028530670470756064)
# ((u'link_click', u'navigation-reload'), 0.0014265335235378032)
# ((u'link_click', u'tab-close'), 0.0014265335235378032)
# ((u'navigation-link', u'navigation-manual_subframe'), 0.0014265335235378032)
# ((u'navigation-manual_subframe', u'tab-close'), 0.0014265335235378032)
# ((u'navigation-omni_query', u'link_click'), 0.0014265335235378032)
# ((u'navigation-omni_query', u'navigation-form_submit'), 0.0014265335235378032)
# ((u'navigation-omni_query', u'navigation-manual_subframe'), 0.0014265335235378032)
# ((u'navigation-omni_query', u'navigation-omni_query'), 0.0014265335235378032)
# ((u'navigation-omni_query', u'navigation-omni_url'), 0.0014265335235378032)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.0014265335235378032)
# ((u'navigation-omni_url', u'navigation-omni_url'), 0.0014265335235378032)
# ((u'tab-close', u'tab-switch'), 0.0014265335235378032)
# ((u'tab-close-switch', u'navigation-manual_subframe'), 0.0014265335235378032)
# ((u'tab-close-switch', u'navigation-reload'), 0.0014265335235378032)
# ((u'tab-close-switch', u'tab-loaded'), 0.0014265335235378032)
# ((u'tab-close-switch', u'tab-search'), 0.0014265335235378032)
# ((u'tab-loaded', u'navigation-omni_url'), 0.0014265335235378032)
# ((u'tab-open-in-new', u'navigation-link'), 0.0014265335235378032)
# ((u'tab-open-in-new', u'tab-close'), 0.0014265335235378032)
# ((u'tab-replace-switch', u'link_click'), 0.0014265335235378032)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.0014265335235378032)
# ((u'tab-switch', u'navigation-manual_subframe'), 0.0014265335235378032)
# ((u'tab-switch', u'navigation-omni_url'), 0.0014265335235378032)
# ((u'tab-switch', u'tab-new'), 0.0014265335235378032)
# ((u'tab-switch', u'tab-search'), 0.0014265335235378032)
# ((u'tab-loaded', u'link_click'), 0.09124844462878473)
# ((u'navigation-link', u'tab-loaded'), 0.09083367897138117)
# ((u'link_click', u'navigation-link'), 0.05848195769390294)
# ((u'tab-close', u'tab-close-switch'), 0.04603898797179593)
# ((u'tab-switch', u'tab-switch'), 0.03940273745333887)
# ((u'link_click', u'link_click'), 0.03484031522189963)
# ((u'tab-loaded', u'tab-loaded'), 0.03442554956449606)
# ((u'tab-new', u'tab-new-switch'), 0.034010783907092494)
# ((u'tab-new-switch', u'navigation-omni_url'), 0.03359601824968893)
# ((u'tab-close-switch', u'tab-close'), 0.02364164247200332)
# ((u'link_click', u'tab-loaded'), 0.023226876814599753)
# ((u'tab-loaded', u'tab-close'), 0.022397345499792616)
# ((u'tab-loaded', u'navigation-link'), 0.01907922024056408)
# ((u'navigation-link-forward_back', u'tab-loaded'), 0.018664454583160513)
# ((u'tab-loaded', u'tab-switch'), 0.01783492326835338)
# ((u'tab-search', u'navigation-omni_query'), 0.01783492326835338)
# ((u'navigation-omni_query', u'tab-loaded'), 0.017420157610949814)
# ((u'tab-open-in-new', u'tab-switch'), 0.017420157610949814)
# ((u'tab-loaded', u'tab-search'), 0.015761094981335544)
# ((u'navigation-form_submit', u'tab-loaded'), 0.015346329323931979)
# ((u'navigation-omni_url', u'tab-search'), 0.01493156366652841)
# ((u'navigation-omni_url', u'tab-loaded'), 0.014102032351721278)
# ((u'tab-loaded', u'tab-new'), 0.013687266694317711)
# ((u'tab-switch', u'navigation-link'), 0.013687266694317711)
# ((u'navigation-omni_url', u'navigation-omni_url'), 0.012028204064703443)
# ((u'tab-search', u'tab-loaded'), 0.012028204064703443)
# ((u'tab-loaded', u'navigation-link-forward_back'), 0.011613438407299876)
# ((u'form_submit', u'navigation-form_submit'), 0.010783907092492741)
# ((u'link_click', u'tab-open-in-new'), 0.009954375777685608)
# ((u'tab-loaded', u'form_submit'), 0.009124844462878473)
# ((u'tab-loaded', u'tab-open-in-new'), 0.007465781833264205)
# ((u'navigation-link', u'link_click'), 0.007051016175860639)
# ((u'navigation-manual_subframe', u'tab-loaded'), 0.007051016175860639)
# ((u'tab-loaded', u'navigation-manual_subframe'), 0.006636250518457071)
# ((u'tab-open-in-new', u'navigation-link'), 0.006636250518457071)
# ((u'navigation-start_page', u'tab-loaded'), 0.006221484861053505)
# ((u'tab-close', u'tab-new'), 0.006221484861053505)
# ((u'tab-close-switch', u'tab-switch'), 0.006221484861053505)
# ((u'tab-switch', u'tab-close'), 0.006221484861053505)
# ((u'navigation-reload', u'tab-loaded'), 0.005806719203649938)
# ((u'tab-switch', u'tab-new'), 0.005806719203649938)
# ((u'tab-close-switch', u'tab-new'), 0.005391953546246371)
# ((u'tab-switch', u'navigation-start_page'), 0.005391953546246371)
# ((u'navigation-omni_url-forward_back', u'tab-loaded'), 0.004977187888842804)
# ((u'tab-loaded', u'navigation-omni_url-forward_back'), 0.004977187888842804)
# ((u'tab-search', u'navigation-link-forward_back'), 0.004562422231439237)
# ((u'tab-search', u'navigation-omni_query-forward_back'), 0.004562422231439237)
# ((u'tab-switch', u'link_click'), 0.004562422231439237)
# ((u'tab-switch', u'tab-loaded'), 0.004562422231439237)
# ((u'navigation-omni_query-forward_back', u'tab-loaded'), 0.00414765657403567)
# ((u'tab-close', u'tab-close'), 0.00414765657403567)
# ((u'navigation-link-forward_back', u'navigation-link-forward_back'), 0.0037328909166321027)
# ((u'link_click', u'tab-search'), 0.0033181252592285357)
# ((u'tab-replaced', u'tab-replace-switch'), 0.0033181252592285357)
# ((u'link_click', u'form_submit'), 0.002903359601824969)
# ((u'tab-close-switch', u'link_click'), 0.002903359601824969)
# ((u'tab-loaded', u'navigation-omni_url'), 0.002903359601824969)
# ((u'link_click', u'tab-switch'), 0.002488593944421402)
# ((u'navigation-omni_url', u'navigation-link'), 0.002488593944421402)
# ((u'tab-close', u'tab-open-in-new'), 0.002488593944421402)
# ((u'tab-close-switch', u'tab-open-in-new'), 0.002488593944421402)
# ((u'link_click', u'navigation-form_submit'), 0.002073828287017835)
# ((u'link_click', u'tab-new'), 0.002073828287017835)
# ((u'link_click', u'tab-replaced'), 0.002073828287017835)
# ((u'navigation-link', u'tab-search'), 0.002073828287017835)
# ((u'navigation-omni_url', u'tab-close'), 0.002073828287017835)
# ((u'link_click', u'tab-close'), 0.0016590626296142678)
# ((u'navigation-link', u'navigation-link'), 0.0016590626296142678)
# ((u'navigation-omni_url', u'tab-open-in-new'), 0.0016590626296142678)
# ((u'tab-close-switch', u'navigation-reload'), 0.0016590626296142678)
# ((u'tab-close-switch', u'tab-search'), 0.0016590626296142678)
# ((u'tab-loaded', u'navigation-reload'), 0.0016590626296142678)
# ((u'tab-search', u'navigation-form_submit'), 0.0016590626296142678)
# ((u'tab-switch', u'navigation-link-forward_back'), 0.0016590626296142678)
# ((u'tab-switch', u'navigation-omni_url'), 0.0016590626296142678)
# ((u'form_submit', u'navigation-link'), 0.001244296972210701)
# ((u'form_submit', u'tab-search'), 0.001244296972210701)
# ((u'navigation-link', u'tab-switch'), 0.001244296972210701)
# ((u'navigation-omni_url', u'link_click'), 0.001244296972210701)
# ((u'navigation-omni_url', u'tab-replaced'), 0.001244296972210701)
# ((u'tab-close', u'tab-switch'), 0.001244296972210701)
# ((u'tab-replace-switch', u'link_click'), 0.001244296972210701)
# ((u'tab-switch', u'tab-open-in-new'), 0.001244296972210701)
# ((u'link_click', u'navigation-link-forward_back'), 0.0008295313148071339)
# ((u'navigation-link', u'navigation-link-forward_back'), 0.0008295313148071339)
# ((u'navigation-omni_url', u'form_submit'), 0.0008295313148071339)
# ((u'navigation-omni_url', u'tab-switch'), 0.0008295313148071339)
# ((u'tab-close', u'navigation-reload'), 0.0008295313148071339)
# ((u'tab-close-switch', u'navigation-omni_url'), 0.0008295313148071339)
# ((u'tab-close-switch', u'tab-loaded'), 0.0008295313148071339)
# ((u'tab-loaded', u'navigation-start_page'), 0.0008295313148071339)
# ((u'tab-replace-switch', u'navigation-link'), 0.0008295313148071339)
# ((u'tab-switch', u'form_submit'), 0.0008295313148071339)
# ((u'tab-switch', u'navigation-manual_subframe'), 0.0008295313148071339)
# ((u'tab-switch', u'navigation-reload'), 0.0008295313148071339)
# ((u'form_submit', u'form_submit'), 0.00041476565740356696)
# ((u'form_submit', u'tab-loaded'), 0.00041476565740356696)
# ((u'form_submit', u'tab-switch'), 0.00041476565740356696)
# ((u'link_click', u'navigation-reload'), 0.00041476565740356696)
# ((u'navigation-form_submit', u'navigation-link'), 0.00041476565740356696)
# ((u'navigation-form_submit', u'tab-new'), 0.00041476565740356696)
# ((u'navigation-link', u'navigation-form_submit'), 0.00041476565740356696)
# ((u'navigation-link', u'navigation-omni_url'), 0.00041476565740356696)
# ((u'navigation-link', u'navigation-omni_url-forward_back'), 0.00041476565740356696)
# ((u'navigation-link', u'tab-new'), 0.00041476565740356696)
# ((u'navigation-link-forward_back', u'link_click'), 0.00041476565740356696)
# ((u'navigation-link-forward_back', u'navigation-omni_url-forward_back'), 0.00041476565740356696)
# ((u'navigation-link-forward_back', u'tab-search'), 0.00041476565740356696)
# ((u'navigation-manual_subframe', u'navigation-link'), 0.00041476565740356696)
# ((u'navigation-omni_query', u'link_click'), 0.00041476565740356696)
# ((u'navigation-omni_query-forward_back', u'tab-search'), 0.00041476565740356696)
# ((u'navigation-omni_url-forward_back', u'navigation-form_submit'), 0.00041476565740356696)
# ((u'navigation-omni_url-forward_back', u'tab-close'), 0.00041476565740356696)
# ((u'navigation-omni_url-forward_back', u'tab-search'), 0.00041476565740356696)
# ((u'tab-close-switch', u'navigation-link-forward_back'), 0.00041476565740356696)
# ((u'tab-loaded', u'navigation-form_submit'), 0.00041476565740356696)
# ((u'tab-new-switch', u'tab-switch'), 0.00041476565740356696)
# ((u'tab-open-in-new', u'link_click'), 0.00041476565740356696)
# ((u'tab-open-in-new', u'tab-close'), 0.00041476565740356696)
# ((u'tab-open-in-new', u'tab-search'), 0.00041476565740356696)
# ((u'tab-replace-switch', u'form_submit'), 0.00041476565740356696)
# ((u'tab-replace-switch', u'tab-loaded'), 0.00041476565740356696)
# ((u'tab-replace-switch', u'tab-search'), 0.00041476565740356696)
# ((u'tab-search', u'navigation-link'), 0.00041476565740356696)
# ((u'tab-search', u'navigation-reload'), 0.00041476565740356696)
# ((u'tab-switch', u'navigation-form_submit'), 0.00041476565740356696)
# ((u'tab-switch', u'navigation-omni_url-forward_back'), 0.00041476565740356696)
# ((u'tab-switch', u'tab-search'), 0.00041476565740356696)

# %% [markdown]
# ### Heuristic rules for segmentations and task label assignment:
# * R1: A time gap > 30 min makes a split (it doesn't matter if eventually two consecutive segments have the same task label)
# * R2: Continuous operations on the same page can be merged unless they have different task labels
#
# * R3: Events within the same segment are assigned to the same task label
# * R4: events outside any labeled segments should be checked

# %%
###### Task sessions
for u in allUsers:
    userid = u['userid']
    user_log = Log.aggregate([
            {'$match': {'userid': userid, 'removed': False}},
            {'$project': {
                'userid': 1,
                'event': 1,
                'timestamp_bson': 1,
                'url': 1,
                'taskname': {'$ifNull': ['$annotation.task.name', 'NA']},
                'taskid': {'$ifNull': ['$annotation.task.taskid', 'NA']},
                'title': {'$ifNull': ['$details.current_tab.title', 'NA']}
                }},
            {'$sort':{'timestamp_bson': pymongo.ASCENDING}} 
            ])
    user_log = list(user_log)

    # Pass 1: split the data by time gap
    segments = []
    current_entry = user_log[0]
    s = []
    for l in user_log[1:]:
        # Time gap in minute, if gap > 30 mins, split
        gap = (l['timestamp_bson'] - current_entry['timestamp_bson']).total_seconds()/60
        # Same page check
        same_page = (l['url'] == current_entry['url'])
        if same_page == False or gap > 30:
            segments.append(s)
            s = []
        current_entry = l
        s.append(current_entry)
    segments.append(s)
   
    for s in segments:
        tasklabels = list(set([x['taskname'] for x in s]))
        if 'NA' in tasklabels:
            tasklabels.remove('NA')
        if len(tasklabels)>1:
            print tasklabels
            for x in s:
                print x['event'], x['taskname'], x['url']
# Out:
# [u'Not sure', u'Write SIGIR paper']
# tab-search Write SIGIR paper https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=multiple%20lines%20inside%20braces%20late
# navigation-omni_query-forward_back NA https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=multiple%20lines%20inside%20braces%20late
# tab-loaded Not sure https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=multiple%20lines%20inside%20braces%20late
# link_click NA https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=multiple%20lines%20inside%20braces%20late
# [u'Not sure', u'Walthamstow Labour organising']
# tab-search Not sure https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=3&ved=0CEIQygQwAmoVChMIsrPZwPTdyAIVhlgaCh0apgI6&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FDisability%23People-first_language&usg=AFQjCNHhrOutbQ-oHC8WcAFREqOSPkE3nQ&sig2=FkzNKEOjVahssmpfTNiN8A&bvm=bv.105841590,d.bGg&cad=rja
# navigation-link NA https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=3&ved=0CEIQygQwAmoVChMIsrPZwPTdyAIVhlgaCh0apgI6&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FDisability%23People-first_language&usg=AFQjCNHhrOutbQ-oHC8WcAFREqOSPkE3nQ&sig2=FkzNKEOjVahssmpfTNiN8A&bvm=bv.105841590,d.bGg&cad=rja
# tab-loaded Walthamstow Labour organising https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=3&ved=0CEIQygQwAmoVChMIsrPZwPTdyAIVhlgaCh0apgI6&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FDisability%23People-first_language&usg=AFQjCNHhrOutbQ-oHC8WcAFREqOSPkE3nQ&sig2=FkzNKEOjVahssmpfTNiN8A&bvm=bv.105841590,d.bGg&cad=rja
# [u'Walthamstow Labour organising', u'Entertainment']
# tab-search Entertainment https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=helena%20hauff
# tab-loaded Walthamstow Labour organising https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=helena%20hauff
# [u'Not sure', u'News update']
# tab-search News update https://www.google.com/url?q=http://www.commitment4p.com&sa=D&usg=AFQjCNHvJWg9fe8W-YpNg0d82vioSnU-og
# navigation-link NA https://www.google.com/url?q=http://www.commitment4p.com&sa=D&usg=AFQjCNHvJWg9fe8W-YpNg0d82vioSnU-og
# tab-loaded Not sure https://www.google.com/url?q=http://www.commitment4p.com&sa=D&usg=AFQjCNHvJWg9fe8W-YpNg0d82vioSnU-og
# [u'SIGIR mobile apps paper', u'Not sure']
# tab-search SIGIR mobile apps paper https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=proposition%20of%20the%20context-aware%20interface%20for%20cellular%20phone
# navigation-omni_query-forward_back NA https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=proposition%20of%20the%20context-aware%20interface%20for%20cellular%20phone
# tab-loaded Not sure https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=proposition%20of%20the%20context-aware%20interface%20for%20cellular%20phone
# link_click NA https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=proposition%20of%20the%20context-aware%20interface%20for%20cellular%20phone
# [u'Not sure', u'Calculate features in client s...']
# tab-open-in-new NA https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=2&ved=0CCYQFjABahUKEwi8w96YieXIAhUDqxoKHWNAAzQ&url=https%3A%2F%2Fgist.github.com%2F4756344&usg=AFQjCNHkIhKLPWnLgX8MrOuLcyENeFyBWw&sig2=GgGS8yUTnfoX4q7SPEiLUQ&cad=rja
# tab-search Not sure https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=2&ved=0CCYQFjABahUKEwi8w96YieXIAhUDqxoKHWNAAzQ&url=https%3A%2F%2Fgist.github.com%2F4756344&usg=AFQjCNHkIhKLPWnLgX8MrOuLcyENeFyBWw&sig2=GgGS8yUTnfoX4q7SPEiLUQ&cad=rja
# navigation-link NA https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=2&ved=0CCYQFjABahUKEwi8w96YieXIAhUDqxoKHWNAAzQ&url=https%3A%2F%2Fgist.github.com%2F4756344&usg=AFQjCNHkIhKLPWnLgX8MrOuLcyENeFyBWw&sig2=GgGS8yUTnfoX4q7SPEiLUQ&cad=rja
# tab-loaded Calculate features in client s... https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=2&ved=0CCYQFjABahUKEwi8w96YieXIAhUDqxoKHWNAAzQ&url=https%3A%2F%2Fgist.github.com%2F4756344&usg=AFQjCNHkIhKLPWnLgX8MrOuLcyENeFyBWw&sig2=GgGS8yUTnfoX4q7SPEiLUQ&cad=rja
# [u'Not sure', u'Write SIGIR paper']
# tab-open-in-new NA https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=4&ved=0CD0QFjADahUKEwiD_LCRoOXIAhVJVRoKHSQ2CpQ&url=ftp%3A%2F%2Fftp.esat.kuleuven.be%2Fsista%2Fida%2Freports%2F05-77.pdf&usg=AFQjCNEs6DtHb4rSzNNaAsXtfkakX9jWEw&sig2=ywGP1aS0xZlRvgABFAmljw&bvm=bv.106130839,d.bGQ&cad=rja
# tab-search Not sure https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=4&ved=0CD0QFjADahUKEwiD_LCRoOXIAhVJVRoKHSQ2CpQ&url=ftp%3A%2F%2Fftp.esat.kuleuven.be%2Fsista%2Fida%2Freports%2F05-77.pdf&usg=AFQjCNEs6DtHb4rSzNNaAsXtfkakX9jWEw&sig2=ywGP1aS0xZlRvgABFAmljw&bvm=bv.106130839,d.bGQ&cad=rja
# navigation-link NA https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=4&ved=0CD0QFjADahUKEwiD_LCRoOXIAhVJVRoKHSQ2CpQ&url=ftp%3A%2F%2Fftp.esat.kuleuven.be%2Fsista%2Fida%2Freports%2F05-77.pdf&usg=AFQjCNEs6DtHb4rSzNNaAsXtfkakX9jWEw&sig2=ywGP1aS0xZlRvgABFAmljw&bvm=bv.106130839,d.bGQ&cad=rja
# tab-loaded Write SIGIR paper https://www.google.co.uk/url?sa=t&rct=j&q=&esrc=s&source=web&cd=4&ved=0CD0QFjADahUKEwiD_LCRoOXIAhVJVRoKHSQ2CpQ&url=ftp%3A%2F%2Fftp.esat.kuleuven.be%2Fsista%2Fida%2Freports%2F05-77.pdf&usg=AFQjCNEs6DtHb4rSzNNaAsXtfkakX9jWEw&sig2=ywGP1aS0xZlRvgABFAmljw&bvm=bv.106130839,d.bGQ&cad=rja
# [u'SIGIR mobile apps paper', u'Not sure']
# tab-search SIGIR mobile apps paper https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=mobileminer%20mining%20your%20frequent%20pattersn
# navigation-omni_query-forward_back NA https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=mobileminer%20mining%20your%20frequent%20pattersn
# tab-loaded Not sure https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=mobileminer%20mining%20your%20frequent%20pattersn
# link_click NA https://www.google.co.uk/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=mobileminer%20mining%20your%20frequent%20pattersn
# [u'Not sure', u'shopping']
# navigation-link NA http://www.mysupermarket.co.uk/tesco-price-comparison/crisps/walkers_crisps_sour_cream_and_chive_6x25g.html
# tab-loaded Not sure http://www.mysupermarket.co.uk/tesco-price-comparison/crisps/walkers_crisps_sour_cream_and_chive_6x25g.html
# navigation-link NA http://www.mysupermarket.co.uk/tesco-price-comparison/crisps/walkers_crisps_sour_cream_and_chive_6x25g.html
# tab-loaded shopping http://www.mysupermarket.co.uk/tesco-price-comparison/crisps/walkers_crisps_sour_cream_and_chive_6x25g.html
# [u'Complete IEP Presentation Slid...', u'Social networking']
# link_click NA https://www.facebook.com/jermenkoo
# tab-loaded Complete IEP Presentation Slid... https://www.facebook.com/jermenkoo
# navigation-link NA https://www.facebook.com/jermenkoo
# tab-loaded Social networking https://www.facebook.com/jermenkoo
